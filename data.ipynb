# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('employee_attrition_2026_master.csv')
dict01 = pd.read_csv('data_dictionary.csv')

# %% [markdown]
# # ตรวจสอบข้อมูล Missing / Duplicate / Data Type

# %%
data

# %%
dict01

# %%
print(f"duplicated = {data.duplicated().sum()}")
print(f"size = {data.size}")
print(f"shape = {data.shape}\n")
print(f"Missing data\n{data.isnull().count()}")

# %%
print(data.dtypes)
